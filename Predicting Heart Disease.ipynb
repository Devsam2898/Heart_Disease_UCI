# %% [markdown]
# # Project 10 : Heart Disease

# %%
# Let us import some of the important data manipulation libraries!
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno #Visualize missing values in your dataset with ease.

# %%
#The most important step in any machine learning project is import the data and analyze it. So lets do it!
hd = pd.read_csv('UCI Heart Disease Data/heart_disease_uci.csv')

# %%
hd.shape
# Out:
# (920, 14)

# %%
hd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 920 entries, 0 to 919
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        920 non-null    int64
#  1   age       920 non-null    int64
#  2   sex       920 non-null    object
#  3   dataset   920 non-null    object
#  4   cp        920 non-null    object
#  5   trestbps  861 non-null    float64
#  6   chol      890 non-null    float64
#  7   fbs       830 non-null    object
#  8   restecg   918 non-null    object
#  9   thalch    865 non-null    float64
#  10  exang     865 non-null    object
#  11  oldpeak   858 non-null    float64
#  12  slope     611 non-null    object
#  13  ca        309 non-null    float64
#  14  thal      434 non-null    object
#  15  num       920 non-null    int64
# dtypes: float64(5), int64(3), object(8)
# memory usage: 115.1+ KB

# %%
hd.head(10)
# Out:
#    id  age     sex    dataset               cp  trestbps   chol    fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0   True
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  False
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  False
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  False
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  False
# 5   6   56    Male  Cleveland  atypical angina     120.0  236.0  False
# 6   7   62  Female  Cleveland     asymptomatic     140.0  268.0  False
# 7   8   57  Female  Cleveland     asymptomatic     120.0  354.0  False
# 8   9   63    Male  Cleveland     asymptomatic     130.0  254.0  False
# 9  10   53    Male  Cleveland     asymptomatic     140.0  203.0   True
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0  False      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0   True      1.5         flat  3.0
# ...

# %% [markdown]
# ### Column Description:-
# 1. id (Unique id for each patient)
# 1. age (Age of the patient in years)
# 1. sex (Male/Female)
# 1. dataset(Cleveland/Hungary/VA Long Beach/Switzerland)
# 1. cp chest pain type ([typical angina, atypical angina, non-anginal, asymptomatic])
# 1. trestbps resting blood pressure (resting blood pressure (in mm Hg on admission to the hospital))
# 1. chol (serum cholesterol in mg/dl)
# 1. fbs (if fasting blood sugar > 120 mg/dl)
# 1. restecg (resting electrocardiographic results) -- Values: [normal, stt abnormality, lv hypertrophy]
# 1. thalach: maximum heart rate achieved
# 1. exang: exercise-induced angina (True/ False)
# 1. oldpeak: ST depression induced by exercise relative to rest
# 1. slope: the slope of the peak exercise ST segment
# 1. ca: number of major vessels (0-3) colored by fluoroscopy
# 1. thal: [normal; fixed defect; reversible defect]
# 1. num: the predicted attribute

# %%
hd.isnull().sum()
# Out:
# id            0
# age           0
# sex           0
# dataset       0
# cp            0
# trestbps     59
# chol         30
# fbs          90
# restecg       2
# thalch       55
# exang        55
# oldpeak      62
# slope       309
# ca          611
# thal        486
# num           0
# dtype: int64

# %%
hd['dataset'].value_counts()
# Out:
# Cleveland        304
# Hungary          293
# VA Long Beach    200
# Switzerland      123
# Name: dataset, dtype: int64

# %%
hd['fbs'].value_counts()
# Out:
# False    692
# True     138
# Name: fbs, dtype: int64

# %%
hd['restecg'].value_counts()
# Out:
# normal              551
# lv hypertrophy      188
# st-t abnormality    179
# Name: restecg, dtype: int64

# %%
hd['exang'].value_counts()
# Out:
# False    528
# True     337
# Name: exang, dtype: int64

# %%
hd['slope'].value_counts()
# Out:
# flat           345
# upsloping      203
# downsloping     63
# Name: slope, dtype: int64

# %%
hd['ca'].value_counts()
# Out:
# 0.0    181
# 1.0     67
# 2.0     41
# 3.0     20
# Name: ca, dtype: int64

# %%
hd['thal'].value_counts()
# Out:
# normal               196
# reversable defect    192
# fixed defect          46
# Name: thal, dtype: int64

# %%
msno.matrix(hd)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (10,5))
for column in hd.columns:
    sns.histplot(data = hd, x = column, bins = 10)
    plt.title(f'Distribution of {column}')
    plt.show()
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\seaborn\distributions.py:461: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   pd.Index(edges, name="edges"),
# C:\Users\Owner\anaconda3\lib\site-packages\seaborn\distributions.py:462: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   pd.Index(widths, name="widths"),
# C:\Users\Owner\anaconda3\lib\site-packages\seaborn\distributions.py:461: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   pd.Index(edges, name="edges"),
# ...

# %%
median_tbps = hd['trestbps'].median()
hd['trestbps'].fillna(median_tbps, inplace = True)
hd['trestbps'].isnull().sum()
# Out:
# 0

# %%
median_chol = hd['chol'].median()
hd['chol'].fillna(median_chol, inplace = True)
hd['chol'].isnull().sum()
# Out:
# 0

# %%
hd['fbs'].fillna(method = 'ffill', inplace = True)
hd['fbs'].isnull().sum()
# Out:
# 0

# %%
hd['restecg'].fillna(method = 'ffill', inplace = True)
hd['restecg'].isnull().sum()
# Out:
# 0

# %%
median_thalch = hd['thalch'].median()
hd['thalch'].fillna(median_thalch, inplace = True)
hd['thalch'].isnull().sum()
# Out:
# 0

# %%
hd['exang'].fillna(method = 'ffill', inplace = True)
hd['exang'].isnull().sum()
# Out:
# 0

# %%
median_op = hd['oldpeak'].median()
hd['oldpeak'].fillna(median_op, inplace = True)
hd['oldpeak'].isnull().sum()
# Out:
# 0

# %%
hd['slope'].fillna(method = 'ffill', inplace = True)
hd['slope'].isnull().sum()
# Out:
# 0

# %%
hd['ca'].fillna(method = 'ffill', inplace = True)
hd['ca'].isnull().sum()
# Out:
# 0

# %%
hd['thal'].fillna(method = 'ffill', inplace = True)
hd['thal'].isnull().sum()
# Out:
# 0

# %%
corr_mat = hd.corr()
plt.figure(figsize = (10,7))
sns.heatmap(corr_mat, annot= True)
plt.title('Correlation between data', fontsize = 15)
plt.show()

# %%
for column in hd.columns:
    # Create a scatter plot for the current column
    plt.scatter(hd[column], hd['num'])  # Assuming 'target' is the target variable
    plt.xlabel(column)
    plt.ylabel('target')
    plt.title(f'Scatter plot: {column}')
    plt.show()

# %%
for column in hd.columns:
    # Create a scatter plot for the current column
    plt.bar(hd[column], hd['num'])  # Assuming 'target' is the target variable
    plt.xlabel(column)
    plt.ylabel('target')
    plt.title(f'Bar plot: {column}')
    plt.show()

# %%
#Lets drop the unwanted columns from the dataset to remove abnormalities!
hd.drop(['id','dataset'], axis = 'columns', inplace = True)

# %%
#Time to import machine learning libraries for model building analysis....
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,accuracy_score
import graphviz

# %%
from sklearn.preprocessing import LabelEncoder

# %%
hd_le = LabelEncoder()

# %%
encoded_col_sex = hd_le.fit_transform(hd['sex'])

# %%
hd['sex'] = encoded_col_sex

# %%
encoded_col_cp = hd_le.fit_transform(hd['cp'])

# %%
hd['cp'] = encoded_col_cp

# %%
encoded_col_fbs = hd_le.fit_transform(hd['fbs'])

# %%
hd['fbs'] = encoded_col_fbs

# %%
encoded_col_restecg = hd_le.fit_transform(hd['restecg'])

# %%
hd['restecg'] = encoded_col_restecg

# %%
encoded_col_exang = hd_le.fit_transform(hd['exang'])

# %%
hd['exang'] = encoded_col_exang

# %%
encoded_col_slope = hd_le.fit_transform(hd['slope'])

# %%
hd['slope'] = encoded_col_slope

# %%
encoded_col_thal = hd_le.fit_transform(hd['thal'])

# %%
hd['thal'] = encoded_col_thal

# %%
hd.head()
# Out:
#    age  sex  cp  trestbps   chol  fbs  restecg  thalch  exang  oldpeak  slope  \
# 0   63    1   3     145.0  233.0    1        0   150.0      0      2.3      0
# 1   67    1   0     160.0  286.0    0        0   108.0      1      1.5      1
# 2   67    1   0     120.0  229.0    0        0   129.0      1      2.6      1
# 3   37    1   2     130.0  250.0    0        1   187.0      0      3.5      0
# 4   41    0   1     130.0  204.0    0        0   172.0      0      1.4      2
#
#     ca  thal  num
# 0  0.0     0    0
# 1  3.0     1    2
# 2  2.0     2    1
# 3  0.0     1    0
# 4  0.0     1    0

# %%
X = hd.iloc[:, :-1]
y = hd.iloc[:, -1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7,random_state= 40)

# %%
logreg = LogisticRegression()

# %%
logreg.fit(X_train, y_train)
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred1 = logreg.predict(X_test)

# %%
conf_matrix1 = confusion_matrix(y_test, y_pred1)
conf_matrix1
# Out:
# array([[120,  19,   0,   0,   0],
#        [ 20,  40,   0,   3,   0],
#        [ 10,  28,   0,   4,   0],
#        [  4,  18,   0,   7,   0],
#        [  0,   2,   0,   1,   0]], dtype=int64)

# %%
accu_score1 = accuracy_score(y_test, y_pred1)
accu_score1
# Out:
# 0.605072463768116

# %%
logreg.score(X_test, y_test)
# Out:
# 0.605072463768116

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2 = dt.predict(X_test)

# %%
conf_matrix2 = confusion_matrix(y_test, y_pred2)
conf_matrix2
# Out:
# array([[101,  20,  10,   7,   1],
#        [ 16,  32,   6,   8,   1],
#        [  6,  16,  13,   7,   0],
#        [  4,  15,   5,   4,   1],
#        [  0,   0,   2,   0,   1]], dtype=int64)

# %%
accu_score2 = accuracy_score(y_test, y_pred2)
accu_score2
# Out:
# 0.5471014492753623

# %%
dt.score(X_test, y_test)
# Out:
# 0.5471014492753623

# %%
from sklearn import tree

# %%
class_names = ['No Heart Disease',
               'Heart Disease Level 1',
               'Heart Disease Level 2',
               'Heart Disease Level 3',
               'Heart Disease Level 4']

dot_data = tree.export_graphviz(dt, out_file=None,
                                feature_names=hd.columns[:-1].tolist(),
                                class_names=class_names,
                                filled=True, rounded=True,
                                special_characters=True)

# %%
# Create a graph from the graph representation
graph = graphviz.Source(dot_data)

# Display the decision tree graph
graph.view()
# Out:
# 'Source.gv.pdf'

# %%
plt.figure(figsize = (8,5))
class_names = ['No Heart Disease',
               'Heart Disease Level 1',
               'Heart Disease Level 2',
               'Heart Disease Level 3',
               'Heart Disease Level 4']

dot_data = tree.export_graphviz(dt, out_file=None,
                                feature_names=hd.columns[:-1],
                                class_names=class_names,
                                filled=True, rounded=True,
                                special_characters=True)

graph = graphviz.Source(dot_data)
graph.render(filename='decision_tree', format='png')  # Save the rendered output as a PNG file

graph

# %%
rand_forr = RandomForestClassifier(n_estimators= 100, random_state= 42)

# %%
rand_forr.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred3 = rand_forr.predict(X_test,)

# %%
conf_matrix3 = confusion_matrix(y_test, y_pred3)
conf_matrix3
# Out:
# array([[117,  19,   2,   1,   0],
#        [ 17,  39,   3,   4,   0],
#        [  9,  24,   3,   6,   0],
#        [  1,  23,   1,   4,   0],
#        [  1,   1,   0,   1,   0]], dtype=int64)

# %%
accu_score3 = accuracy_score(y_test, y_pred3)
accu_score3
# Out:
# 0.5905797101449275

# %%
class_names = ['No Heart Disease',
               'Heart Disease Level 1',
               'Heart Disease Level 2',
               'Heart Disease Level 3',
               'Heart Disease Level 4']
rand_forr1 = rand_forr.estimators_[0]
dot_data1 = tree.export_graphviz(rand_forr1, out_file=None,
                                feature_names=hd.columns[:-1],
                                class_names=class_names,
                                filled=True, rounded=True,
                                special_characters=True)

graph = graphviz.Source(dot_data)
graph.render(filename='decision_tree', format='png')  # Save the rendered output as a PNG file

graph

# %%
rand_forr.score(X_test, y_test)
# Out:
# 0.5905797101449275
